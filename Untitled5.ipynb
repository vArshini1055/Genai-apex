# %% [markdown]
# <a href="https://colab.research.google.com/github/vArshini1055/Genai-apex/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyA1nS0KwYOxVlowu5Xou5gCPTyHT_7qfRo")

# %%
for i in genai.list_models():
  print(i.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-exp-1206
# models/gemini-exp-1121
# models/gemini-exp-1114
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# ...

# %%
model=genai.GenerativeModel("gemini-pro")

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
res=model.generate_content("List out the districts in tamil nadu")

# %%
res.text
# Out:
# '1. Ariyalur\n2. Chennai\n3. Coimbatore\n4. Cuddalore\n5. Dharmapuri\n6. Dindigul\n7. Erode\n8. Kanchipuram\n9. Kanyakumari\n10. Karur\n11. Krishnagiri\n12. Madurai\n13. Nagapattinam\n14. Namakkal\n15. Nilgiris\n16. Perambalur\n17. Pudukkottai\n18. Ramanathapuram\n19. Salem\n20. Sivagangai\n21. Tenkasi\n22. Thanjavur\n23. Theni\n24. Thoothukudi\n25. Tiruchirappalli\n26. Tirunelveli\n27. Tiruppur\n28. Tiruvallur\n29. Tiruvannamalai\n30. Tiruvarur\n31. Vellore\n32. Villupuram\n33. Virudhunagar'

# %%
vision_model=genai.GenerativeModel("gemini-pro-vision")

# %%
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
vision_model=genai.GenerativeModel("gemini-1.5-flash")
vision_model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
from PIL import Image
img=Image.open("/content/cricket.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x342>

# %%
vision_model.generate_content(["explain this image",img]).text
# Out:
# "That's a photo of the Indian national cricket team.  The image shows a group of male cricket players in their blue team uniforms.  They're likely either celebrating a victory or preparing for a match.  The players are standing close together, suggesting camaraderie and team spirit.  The setting appears to be a stadium, judging by the background which is blurred but shows stands filled with spectators.\n"

# %%
vision_model1.generate_content(["explain who are the persons in image",img]).text
# Out:
# "That's the Indian cricket team.  While I can't name every single player with certainty from just this image,  the most prominent figure is **Virat Kohli**, the former captain of the Indian cricket team,  easily identifiable by his pose and his general prominence.  Other players are members of the Indian national cricket team around the time the photo was taken.  Pinpointing all of them would require more information such as the specific match or year.\n"
